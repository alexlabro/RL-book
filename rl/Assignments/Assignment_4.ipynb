# %% [markdown]
# ## Question 1 :
# I did the calculus on paper here are my results :
#
# $q_1(s_1,a_1) = 10.6 , q_1(s_1,a_2) = 11.2$ \
# $q_1(s_2,a_1) = 4.3 , q_1(s_2,a_2) = 4.3$ \
# We have $\pi^1(s_1)=a_1$ and $\pi^1(s_2)=a_1 or a_2$
#
# Using the same method, $\pi^2(s_1)=a_1$ and $\pi^2(s_2)=a_2$
#
# To evaluate the deterministic policy for $k>2$ we evaluate $q(s_1,a_1) - q(s_1,a_2)$ and $q(s_2,a_1) - q(s_2,a_2)$
#
# The key point is that with value iteration, at each iteration the value function is bigger than at the precedent step, for each state.
#
# $$q(s_2,a_1) - q(s_2,a_2) = 2 - 0.2V(s_1)$$ and as we have $V(s_1)>10, \pi(s_2) = a_2$
#
# Same, $$q(s_1,a_1) - q(s_1,a_2) = 0.1V(s_1) + 0.4V(s_2) - 2$$ as we have $V(s_1) > 10$ and $ V(s_2)>4$, $\pi(s_1)=a_1$

# %% [markdown]
# ## Question 4

# %%
import os
os.chdir('/Users/Alex/Desktop/Documents_4A/Winter_quarter_1/MS&E_346/RL_book/')

# %%
from dataclasses import dataclass
from typing import Tuple, Dict, Mapping
from rl.markov_decision_process import FiniteMarkovDecisionProcess
from rl.policy import FiniteDeterministicPolicy
from rl.markov_process import FiniteMarkovProcess, FiniteMarkovRewardProcess
from rl.distribution import Categorical
from scipy.stats import poisson

# %%
## Defining the markov decision process

k1 = 2
k2 = 5

@dataclass(frozen=True)
class DoubleInventoryState:
    on_hand_1: int
    on_hand_2: int
    on_order_1: int
    on_order_2:int

    def inventory_position(self) -> int:
        return (self.on_hand_1 + self.on_order_1, self.on_hand_2 + self.on_order_2)


InvOrderMapping = Mapping[
    DoubleInventoryState,
    Mapping[int, Categorical[Tuple[DoubleInventoryState, float]]]
]


class DoubleInventoryMDPCap(FiniteMarkovDecisionProcess[DoubleInventoryState, int]):

    def __init__(
        self,
        capacity_1: int,
        capacity_2: int,
        poisson_lambda_1: float,
        poisson_lambda_2:float,
        holding_cost_1: float,
        holding_cost_2: float,
        stockout_cost_1: float,
        stockout_cost_2: float
    ):
        self.capacity_1: int = capacity_1
        self.poisson_lambda_1: float = poisson_lambda_1
        self.holding_cost_1: float = holding_cost_1
        self.stockout_cost_1: float = stockout_cost_1
        self.capacity_2: int = capacity_2
        self.poisson_lambda_2: float = poisson_lambda_2
        self.holding_cost_2: float = holding_cost_2
        self.stockout_cost_2: float = stockout_cost_2

        self.poisson_distr_1 = poisson(poisson_lambda_1)
        self.poisson_distr_2 = poisson(poisson_lambda_2)
        super().__init__(self.get_action_transition_reward_map())

    def get_action_transition_reward_map(self) -> InvOrderMapping:
        d: Dict[DoubleInventoryState, Dict[Tuple[int,int,int], Categorical[Tuple[DoubleInventoryState,
                                                            float]]]] = {}
        for alpha_1 in range(self.capacity_1 + 1):
            for beta_1 in range(self.capacity_1 + 1 - alpha_1):
                for alpha_2 in range(self.capacity_2 + 1):
                    for beta_2 in range(self.capacity_2 + 1 - alpha_2):
                        state: DoubleInventoryState = DoubleInventoryState(alpha_1, beta_1,alpha_2,beta_2)
                        ip: tuple = state.inventory_position()
                        base_reward_1: float = - self.holding_cost_1 * alpha_1
                        base_reward_2: float = - self.holding_cost_2 * alpha_2
                        d1: Dict[Tuple[int,int,int], Categorical[Tuple[DoubleInventoryState, float]]] = {}
                            
                        for order_1 in range(self.capacity_1 - ip[0] + 1): #Orders of 1
                            for order_2 in range(self.capacity_1 - ip[1] + 1): # Orders of 2
                                for transfer in range(-ip[1],ip[0]): #Convention : transfer is positive from store 1 to 2
                                    sr_probs_dict: Dict[Tuple[DoubleInventoryState, float], float] = {}
                                    for i in range(ip[0]):
                                        for j in range(ip[1]):
                                            sr_probs_dict[(DoubleInventoryState(ip[0] - i, ip[1] - j, order_1,order_2), base_reward_1 + base_reward_2 - k1*(transfer!=0) - k2*(order_1!=0) - k2*(order_2!=0))] =\
                                            self.poisson_distr_1.pmf(i)*self.poisson_distr_2.pmf(j)
                                    for j in range(ip[1]):
                                        prob_1: float = 1 - self.poisson_distr_1.cdf(ip[0] - 1)
                                        reward_1: float = base_reward_1 - self.stockout_cost_1 *(prob_1 * (self.poisson_lambda_1 - ip[0]) + ip[0] * self.poisson_distr_1.pmf(ip[0]))
                                        sr_probs_dict[(DoubleInventoryState(0, ip[1] - j, order_1,order_2), reward_1 + base_reward_2 - k1*(transfer!=0) - k2*(order_1!=0) - k2*(order_2!=0))] =\
                                            prob_1*self.poisson_distr_2.pmf(j)
                                    for i in range(ip[0]):
                                        prob_2: float = 1 - self.poisson_distr_1.cdf(ip[1] - 1)
                                        reward_2: float = base_reward_2 - self.stockout_cost_2 *(prob_2 * (self.poisson_lambda_2 - ip[1]) + ip[1] * self.poisson_distr_2.pmf(ip[1]))
                                        sr_probs_dict[(DoubleInventoryState(ip[0]-i, 0, order_1,order_2), base_reward_1 + reward_2 - k1*(transfer!=0) - k2*(order_1!=0) - k2*(order_2!=0))] =\
                                            prob_2*self.poisson_distr_1.pmf(i)
                                    prob_1: float = 1 - self.poisson_distr_1.cdf(ip[0] - 1)
                                    prob_2: float = 1 - self.poisson_distr_1.cdf(ip[1] - 1)
                                    reward_1: float = base_reward_1 - self.stockout_cost_1 *(prob_1 * (self.poisson_lambda_1 - ip[0]) + ip[0] * self.poisson_distr_1.pmf(ip[0]))
                                    reward_2: float = base_reward_2 - self.stockout_cost_2 *(prob_2 * (self.poisson_lambda_2 - ip[1]) + ip[1] * self.poisson_distr_2.pmf(ip[1]))
                                    sr_probs_dict[(DoubleInventoryState(0, 0, order_1,order_2), reward_1 + reward_2 - k1*(transfer!=0) - k2*(order_1!=0) - k2*(order_2!=0))] =\
                                        prob_1*prob_2
                                    d1[order_1,order_2,transfer] = Categorical(sr_probs_dict)

                        d[state] = d1
        return d

# %%
#Parameters
user_capacity_1 = 3
user_poisson_lambda_1 = 1.0
user_holding_cost_1 = 1.0
user_stockout_cost_1 = 10.0

user_capacity_2 = 2
user_poisson_lambda_2 = 1.5
user_holding_cost_2 = 2.0
user_stockout_cost_2 = 8.0

di_mdp = DoubleInventoryMDPCap(capacity_1=user_capacity_1,
        poisson_lambda_1=user_poisson_lambda_1,
        holding_cost_1=user_holding_cost_1,
        stockout_cost_1=user_stockout_cost_1,
        capacity_2=user_capacity_2,
        poisson_lambda_2=user_poisson_lambda_2,
        holding_cost_2=user_holding_cost_2,
        stockout_cost_2=user_stockout_cost_2)

# %%
print(di_mdp)
# Out:
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0):
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1):
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -17.206] with Probability 0.739
#   With Action (0, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -17.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -22.206] with Probability 0.739
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -22.206] with Probability 0.739
#   With Action (1, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -22.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -27.206] with Probability 0.739
#   With Action (2, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -22.206] with Probability 0.739
#   With Action (2, 1, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=1) and Reward -22.000] with Probability 0.261
#     To [Terminal State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=1) and Reward -27.206] with Probability 0.739
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2):
#   With Action (0, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.959] with Probability 0.321
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.959] with Probability 0.321
#   With Action (1, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (2, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (2, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -19.959] with Probability 0.321
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0):
#   With Action (0, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -17.679] with Probability 0.632
#   With Action (0, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -22.679] with Probability 0.632
#   With Action (0, 2, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -22.679] with Probability 0.632
#   With Action (1, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -22.679] with Probability 0.632
#   With Action (1, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -24.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -27.679] with Probability 0.632
#   With Action (1, 2, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=2) and Reward -24.000] with Probability 0.368
#     To [Terminal State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=2) and Reward -27.679] with Probability 0.632
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1):
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -12.885] with Probability 0.467
#   With Action (0, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.885] with Probability 0.467
#   With Action (0, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -12.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -17.885] with Probability 0.467
#   With Action (0, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -7.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -10.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -12.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -15.885] with Probability 0.467
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -17.885] with Probability 0.467
#   With Action (1, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -7.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -10.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -12.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -15.885] with Probability 0.467
#   With Action (1, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -14.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -17.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -19.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -22.885] with Probability 0.467
#   With Action (1, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -12.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -15.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -17.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -20.885] with Probability 0.467
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0):
#   With Action (0, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -16.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -16.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -17.036] with Probability 0.264
#   With Action (0, 0, 1):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -18.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -18.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -19.036] with Probability 0.264
#   With Action (0, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -22.036] with Probability 0.264
#   With Action (0, 1, 1):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -23.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -23.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -24.036] with Probability 0.264
#   With Action (0, 2, 0):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -22.036] with Probability 0.264
#   With Action (0, 2, 1):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -23.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -23.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -24.036] with Probability 0.264
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0):
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -17.206] with Probability 0.739
#   With Action (0, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -17.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -22.206] with Probability 0.739
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -22.206] with Probability 0.739
#   With Action (1, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -22.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -27.206] with Probability 0.739
#   With Action (2, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.261
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -22.206] with Probability 0.739
#   With Action (2, 1, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=1) and Reward -22.000] with Probability 0.261
#     To [Terminal State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=1) and Reward -27.206] with Probability 0.739
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1):
#   With Action (0, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.959] with Probability 0.321
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.959] with Probability 0.321
#   With Action (1, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (2, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (2, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -19.959] with Probability 0.321
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=2):
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0):
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -12.885] with Probability 0.467
#   With Action (0, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.885] with Probability 0.467
#   With Action (0, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -12.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -17.885] with Probability 0.467
#   With Action (0, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -7.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -10.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -12.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -15.885] with Probability 0.467
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -17.885] with Probability 0.467
#   With Action (1, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -7.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -10.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -12.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -15.885] with Probability 0.467
#   With Action (1, 1, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -14.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -17.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -19.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -22.885] with Probability 0.467
#   With Action (1, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -12.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1) and Reward -15.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -17.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -20.885] with Probability 0.467
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=1):
#   With Action (0, 0, -2):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.638] with Probability 0.203
#   With Action (0, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.638] with Probability 0.203
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -4.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.638] with Probability 0.203
#   With Action (1, 0, -2):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -11.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -15.638] with Probability 0.203
#   With Action (1, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -11.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -15.638] with Probability 0.203
#   With Action (1, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -7.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -7.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -10.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -10.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -9.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -13.638] with Probability 0.203
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0):
#   With Action (0, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -11.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -11.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -12.242] with Probability 0.195
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.242] with Probability 0.195
#   With Action (0, 0, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -11.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -11.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -12.242] with Probability 0.195
#   With Action (0, 1, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -11.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -11.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -12.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -16.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -16.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -17.242] with Probability 0.195
#   With Action (0, 1, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -10.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -15.242] with Probability 0.195
#   With Action (0, 1, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -11.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -11.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -12.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -16.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -16.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -17.242] with Probability 0.195
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0):
#   With Action (0, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.959] with Probability 0.321
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -12.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.959] with Probability 0.321
#   With Action (1, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (1, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (2, 0, -2):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -19.959] with Probability 0.321
#   With Action (2, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.271
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=2, on_order_2=0) and Reward -17.000] with Probability 0.407
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=2, on_order_2=0) and Reward -19.959] with Probability 0.321
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=1):
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=2):
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0):
#   With Action (0, 0, -2):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.638] with Probability 0.203
#   With Action (0, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.638] with Probability 0.203
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -4.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.638] with Probability 0.203
#   With Action (1, 0, -2):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -11.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -15.638] with Probability 0.203
#   With Action (1, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -9.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -12.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -11.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -15.638] with Probability 0.203
#   With Action (1, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -7.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -7.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=0) and Reward -10.679] with Probability 0.172
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=1, on_order_2=0) and Reward -10.679] with Probability 0.257
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -9.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -13.638] with Probability 0.203
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=1, on_order_2=1):
# From State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=2, on_order_2=0):
#   With Action (0, 0, -2):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.996] with Probability 0.085
#   With Action (0, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.996] with Probability 0.085
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.996] with Probability 0.085
#   With Action (0, 0, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -7.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.996] with Probability 0.085
# From State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0):
#   With Action (0, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -13.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -16.679] with Probability 0.632
#   With Action (0, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -18.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -21.679] with Probability 0.632
#   With Action (0, 2, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -18.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -21.679] with Probability 0.632
#   With Action (1, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -18.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=0) and Reward -21.679] with Probability 0.632
#   With Action (1, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -23.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=1) and Reward -26.679] with Probability 0.632
#   With Action (1, 2, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=1, on_order_2=2) and Reward -23.000] with Probability 0.368
#     To [Terminal State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=1, on_order_2=2) and Reward -26.679] with Probability 0.632
# From State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1):
#   With Action (0, 0, -1):
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -3.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.679] with Probability 0.165
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.206] with Probability 0.272
# ...
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.996] with Probability 0.085
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -3.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -3.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -3.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -3.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -5.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -5.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.996] with Probability 0.085
#   With Action (0, 0, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -6.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -6.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.996] with Probability 0.085
# From State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=2, on_order_2=0):
# From State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0):
#   With Action (0, 0, 0):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -14.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -15.036] with Probability 0.264
#   With Action (0, 0, 1):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -16.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -16.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -17.036] with Probability 0.264
#   With Action (0, 1, 0):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -20.036] with Probability 0.264
#   With Action (0, 1, 1):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -22.036] with Probability 0.264
#   With Action (0, 2, 0):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -19.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -20.036] with Probability 0.264
#   With Action (0, 2, 1):
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -21.000] with Probability 0.368
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=2) and Reward -22.036] with Probability 0.264
# From State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1):
#   With Action (0, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.242] with Probability 0.195
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -3.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -8.242] with Probability 0.195
#   With Action (0, 0, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -9.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -10.242] with Probability 0.195
#   With Action (0, 1, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -10.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -15.242] with Probability 0.195
#   With Action (0, 1, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -7.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -7.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -8.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -12.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -12.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -13.242] with Probability 0.195
#   With Action (0, 1, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -9.000] with Probability 0.096
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=1) and Reward -10.036] with Probability 0.069
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -14.206] with Probability 0.272
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=1) and Reward -15.242] with Probability 0.195
# From State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=2):
#   With Action (0, 0, -2):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.996] with Probability 0.085
#   With Action (0, 0, -1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.996] with Probability 0.085
#   With Action (0, 0, 0):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -2.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -3.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -3.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -4.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -4.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -5.996] with Probability 0.085
#   With Action (0, 0, 1):
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [Terminal State DoubleInventoryState(on_hand_1=2, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [Terminal State DoubleInventoryState(on_hand_1=1, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.100
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -4.000] with Probability 0.150
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=2, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.072
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=1, on_order_1=0, on_order_2=0) and Reward -5.036] with Probability 0.108
#     To [State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=1, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -6.959] with Probability 0.118
#     To [State DoubleInventoryState(on_hand_1=0, on_hand_2=0, on_order_1=0, on_order_2=0) and Reward -7.996] with Probability 0.085
# From State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=1, on_order_2=0):
# From State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=1, on_order_2=1):
# From State DoubleInventoryState(on_hand_1=2, on_hand_2=0, on_order_1=2, on_order_2=0):

# %%
#Optimal Value functions
from rl.dynamic_programming import evaluate_mrp_result
from rl.dynamic_programming import policy_iteration_result
from rl.dynamic_programming import value_iteration_result

# %%
value_iteration_result(di_mdp, gamma=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-79947f354d85> in <module>
# ----> 1 value_iteration_result(di_mdp, gamma=1)
#
# ~/Desktop/Documents_4A/Winter_quarter_1/MS&E_346/RL_book/rl/dynamic_programming.py in value_iteration_result(mdp, gamma)
#     166     gamma: float
#     167 ) -> Tuple[V[S], FiniteDeterministicPolicy[S, A]]:
# --> 168     opt_vf: V[S] = converged(
#     169         value_iteration(mdp, gamma),
#     170         done=almost_equal_vfs
#
# ~/Desktop/Documents_4A/Winter_quarter_1/MS&E_346/RL_book/rl/iterate.py in converged(values, done)
#      76
#      77     if result is None:
# ---> 78         raise ValueError("converged called on an empty iterator")
#      79
#      80     return result
#
# ValueError: converged called on an empty iterator
